# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
x= [1,2,3,4]
y= [2,4,6,8]
plt.plot(x,y);

# %%
# fig = plt.figure() # create figure
# ax = fig.add_subplot() # adds some axes
# plt.show()

# %%
# fig = plt.figure() # create figure
# ax = fig.add_axes([1,1,1,1])
# ax.plot(x,y)


# plt.show()

# %%
fig, ax = plt.subplots()
ax.set(title='simple-plot',xlabel='x-axix',ylabel='y-axis')
ax.plot(x,[9,10,3,7.5])
fig.savefig('sample-plot.png')

# %%
x = np.linspace(0,10,100)
y= x**2

# %% [markdown]
# ## line plot

# %%
fig, ax = plt.subplots()
ax.plot(x,y);

# %% [markdown]
# ## Scatter plot

# %%
fig, ax = plt.subplots()
ax.scatter(x,np.sin(x));

# %% [markdown]
# ## Bar plot

# %%
nut_butter_price={
    "Almond Butter": 10,
    "Peanut Butter": 8,
    "Cashew Butter": 12
}

fig, ax = plt.subplots()
ax.set(title='Nut Buttter Price', ylabel='Price', xlabel='Type')
ax.bar(nut_butter_price.keys(), nut_butter_price.values());

# %% [markdown]
# ## Histogram

# %%
x= np.random.randn(1000)
fig, ax = plt.subplots()
ax.hist(x);

# %% [markdown]
# # Subplots

# %%
# option 1
fig, ((ax1,ax2),(ax3,ax4)) = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax1.plot(x,x);
ax2.scatter(np.random.random(10),np.random.randn(10));
ax3.bar(nut_butter_price.keys(), nut_butter_price.values());
ax4.hist(np.random.random(1000));

# %%
# option 2
fig, ax = plt.subplots(nrows=2,ncols=2,figsize=(10,5))
ax[0,0].plot(x,x);
ax[0,1].scatter(np.random.random(10),np.random.randn(10));
ax[1,0].bar(nut_butter_price.keys(), nut_butter_price.values());
ax[1,1].hist(np.random.random(1000));

# %% [markdown]
# ### Ploting From Pandas Dataframe

# %%
car= pd.read_csv('car-sales.csv')

# %%
car["Price"] = car['Price'].str.replace('[\$\,\.]', '', regex=True)
car
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
car["Price"] = car['Price'].str[:-2]

# %%
car['Price'].astype(int)
# Out:
# 0     4000
# 1     5000
# 2     7000
# 3    22000
# 4     3500
# 5     4500
# 6     7500
# 7     7000
# 8     6250
# 9     9700
# Name: Price, dtype: int32

# %%
car['Sale Date'] = pd.date_range('1/1/2022' , periods= 10)
car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date
# 0  Toyota  White         150043      4   4000 2022-01-01
# 1   Honda    Red          87899      4   5000 2022-01-02
# 2  Toyota   Blue          32549      3   7000 2022-01-03
# 3     BMW  Black          11179      5  22000 2022-01-04
# 4  Nissan  White         213095      4   3500 2022-01-05
# 5  Toyota  Green          99213      4   4500 2022-01-06
# 6   Honda   Blue          45698      4   7500 2022-01-07
# 7   Honda   Blue          54738      4   7000 2022-01-08
# 8  Toyota  White          60000      4   6250 2022-01-09
# 9  Nissan  White          31600      4   9700 2022-01-10

# %%
car['Total'] = car['Price'].astype(int).cumsum()
car
# Out:
#      Make Colour  Odometer (KM)  Doors  Price  Sale Date  Total
# 0  Toyota  White         150043      4   4000 2022-01-01   4000
# 1   Honda    Red          87899      4   5000 2022-01-02   9000
# 2  Toyota   Blue          32549      3   7000 2022-01-03  16000
# 3     BMW  Black          11179      5  22000 2022-01-04  38000
# 4  Nissan  White         213095      4   3500 2022-01-05  41500
# 5  Toyota  Green          99213      4   4500 2022-01-06  46000
# 6   Honda   Blue          45698      4   7500 2022-01-07  53500
# 7   Honda   Blue          54738      4   7000 2022-01-08  60500
# 8  Toyota  White          60000      4   6250 2022-01-09  66750
# 9  Nissan  White          31600      4   9700 2022-01-10  76450

# %%
car.plot(x='Sale Date', y='Total');

# %%
car['Price'] = car['Price'].astype(int)
car.plot(x='Odometer (KM)', y='Price', kind='scatter');

# %%
car['Odometer (KM)'].plot.hist(bins = 10);

# %%
heart_disease = pd.read_csv('heart-disease.csv')

# %%
heart_disease['age'].plot.hist();

# %%
heart_disease.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %%
over_50 = heart_disease[heart_disease['age']>50]

# %%
over_50.plot(x='age', y='chol' ,kind='scatter', c='target');

# %% [markdown]
# ### OO method

# %%
fig,ax = plt.subplots(figsize=(10,6))
over_50.plot(x='age', y='chol' ,kind='scatter', c='target',ax=ax);
ax.set_xlim([45,100]);

# %% [markdown]
# ### OO method from scratch

# %%
fig,ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

ax.set(title = "Heart Disease ans Cholestrol Level",
       xlabel = "Age",
       ylabel = "Chplestrol");

ax.legend(*scatter.legend_elements(), title = 'Target');

ax.axhline(over_50['chol'].mean(),
           ls=':',
           lw=3);

# %%
#subplot OO method

fig,(ax0, ax1) = plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter = ax0.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target']);

ax0.set(title = "Heart Disease ans Cholestrol Level",
       ylabel = "Chplestrol");

ax0.legend(*scatter.legend_elements(), title = 'Target');

ax0.axhline(over_50['chol'].mean(),
           ls=':',
           lw=3);

scatter = scatter = ax1.scatter(x=over_50['age'],
                     y=over_50['thalach'],
                     c=over_50['target']);

ax1.set(title = "Heart Disease and Max Heart Rate Level",
       xlabel = "Age",
       ylabel = "Heart Rate");

ax1.legend(*scatter.legend_elements(), title = 'Target');

ax1.axhline(over_50['thalach'].mean(),
           ls='--',
           lw=3);

fig.suptitle('Heart Disease Analysis',fontweight = 'bold', fontsize = 16);

# %% [markdown]
# ### customize Matplotlib plots

# %%
plt.style.use('seaborn-whitegrid')

fig,ax = plt.subplots(figsize=(10,6))
scatter = ax.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'],
                     cmap='winter');

ax.set(title = "Heart Disease ans Cholestrol Level",
       xlabel = "Age",
       ylabel = "Chplestrol");

ax.legend(*scatter.legend_elements(), title = 'Target');

ax.axhline(over_50['chol'].mean(),
           ls=':',
           lw=3);
# Out:
# C:\Users\amthg\AppData\Local\Temp\ipykernel_24188\3899221799.py:1: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use('seaborn-whitegrid')

# %%
fig,(ax0, ax1) = plt.subplots(nrows=2,ncols=1,figsize=(10,10),sharex=True)
scatter = ax0.scatter(x=over_50['age'],
                     y=over_50['chol'],
                     c=over_50['target'],
                     cmap='winter');

ax0.set(title = "Heart Disease ans Cholestrol Level",
       ylabel = "Chplestrol");

ax0.legend(*scatter.legend_elements(), title = 'Target');

ax0.axhline(over_50['chol'].mean(),
           ls='--',
           lw=3,
           c='r');

ax0.set_xlim([50,80])

scatter = scatter = ax1.scatter(x=over_50['age'],
                     y=over_50['thalach'],
                     c=over_50['target'],
                     cmap='winter');

ax1.set(title = "Heart Disease and Max Heart Rate Level",
       xlabel = "Age",
       ylabel = "Heart Rate");

ax1.legend(*scatter.legend_elements(), title = 'Target');

ax1.axhline(over_50['thalach'].mean(),
           ls='--',
           lw=3,
           c='r');
ax1.set_ylim([60,200])

fig.suptitle('Heart Disease Analysis',fontweight = 'bold', fontsize = 16);

# %%
fig

# %%
fig.savefig('Heart-disease-analysis-plot.png')
